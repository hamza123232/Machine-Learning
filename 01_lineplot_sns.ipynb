# %%
# importing libraries *seaborn
# Out:
#   Input In [1]
#     *seaborn*
#     ^
# IndentationError: unexpected indent

# %%
# importing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# loading data-set {default data-set in seaborn}

flower = sns.load_dataset("iris")
# calling flower to print
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## Adding title

# %%
# drawing a line plot
sns.lineplot(x="sepal_length",y="sepal_width", data = flower)
plt.title("Flower Graph")
plt.show()

# %%
## Adding limits

sns.lineplot(x="sepal_length",y="sepal_width", data = flower)
plt.title("Flower Graph")
plt.xlim(4)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## Set Styles
# - darkgrid
# -white grid
# dark

# %%
sns.lineplot(x="sepal_length",y="sepal_width", data = flower)
plt.title("Flower Graph")
plt.xlim(4)
plt.ylim(1)
#sns.set_style(style="whitegrid",rc = None)
sns.set_style("darkgrid")
plt.show()

# %%
## Size of figure

# %%
sns.lineplot(x="sepal_length",y="sepal_width", data = flower)
plt.title("Flower Graph")
plt.xlim(4)
plt.ylim(1)
#
sns.set_style("dark")
sns.set_style(style=None,rc = None)
plt.figure(figsize=(4,2))
plt.show()

# %%
# importing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# loading data-set {default data-set in seaborn}

flower = sns.load_dataset("iris")
# calling flower to print
flower

sns.barplot(x="species",y="sepal_length", data = flower)
plt.show()

# %%
ship = sns.load_dataset("titanic")
ship
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="survived",y="age" ,hue="sex", data=ship)
plt.show()

# %%
sns.barplot(x="survived",y="age" ,hue="sex", data=ship,color="grey")
plt.show()

# %%
sns.barplot(x="survived",y="age" ,hue="sex", data=ship,color="brown",ci= None)
plt.show()

# %%
sns.barplot(x="survived",y="age" ,hue="sex", data=ship,color="brown",ci= None,palette='pastel')
plt.show()

# %%
from statistics import mean, median
import numpy 

sns.barplot(x="survived",y="age" ,hue="sex", data=ship,color="brown",ci= None,palette='pastel',estimator=median)
plt.show()

# %%
sns.barplot(x="survived",y="age" ,hue="sex", data=ship,color="brown",ci= None,palette='pastel',saturation=2)
plt.show()

# %%
sns.barplot(x="fare",y="class" ,hue="sex", data=ship,color="brown",ci= None,palette='pastel',saturation=2)
plt.show()

# %%
import seaborn as sns
import pandas as pd
data = sns.load_dataset("titanic")
titanic = pd.to_csv(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Hamza Durez\Desktop\ML-freecodecamp\01_lineplot_sns.ipynb Cell 19 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hamza%20Durez/Desktop/ML-freecodecamp/01_lineplot_sns.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Hamza%20Durez/Desktop/ML-freecodecamp/01_lineplot_sns.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> data = sns.load_dataset("titanic")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hamza%20Durez/Desktop/ML-freecodecamp/01_lineplot_sns.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> titanic = pd.to_csv(data)
#
# File c:\Users\Hamza Durez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
# ...
